# %%
# pip install beautifulsoup4 lxml

# %%
from bs4 import BeautifulSoup
import html as htmllib
import re

def extract_plain_text(fields):
    """
    fields = article.get("fields", {}) from Guardian API result.
    Returns plain cleaned text or None.
    """
    if not fields:
        return None


    # fallback to HTML body
    body_html = fields.get("body")
    if not body_html:
        return None

    soup = BeautifulSoup(body_html, "lxml")

    # remove unwanted tags (figures, scripts, asides, ads, nav, footer)
    for tag in soup(["script", "style", "aside", "figure", "iframe", "header", "footer", "nav"]):
        tag.decompose()


    # get text with paragraph spacing
    text = soup.get_text(separator=" ")
    text = htmllib.unescape(text)

    # collapse multiple newlines and whitespace
    text = re.sub(
    r"(?im)^\s*(Updated\s+at\s+)?\d{1,2}\.\d{2}\s*(am|pm)\s+BST\s*$", 
    "", 
    text)
    text = re.sub(r'\n\s*\n+', '\n\n', text)   # keep paragraph breaks
    lines = [ln.strip() for ln in text.splitlines()]
    clean = "\n".join([ln for ln in lines if ln])

    # optional: trim extremely long articles (e.g., keep first N chars)
    # clean = clean[:20000]

    return clean

# %%
import requests
import csv
import uuid
from time import sleep

API_KEY = "022783ad-6e46-4ba2-af9a-3a7464467d02"
BASE_URL = "https://content.guardianapis.com/search"
PAGE_SIZE = 200  # max 200

def crawl_guardian(pages, output_file="guardian_articles.csv"):
    all_articles = []

    # open CSV for writing
    with open(output_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f, quoting=csv.QUOTE_ALL)  # quote all fields
        writer.writerow([
            "id", "title", "headline", "url", "thumbnail",
            "section", "published_at", "trail_text", "body", "byline"
        ])

        for page in range(pages, pages + 5):
            params = {
                "api-key": API_KEY,
                "page": page,
                "page-size": PAGE_SIZE,
                "show-fields": "trailText,body,thumbnail,headline,byline",
                "order-by": "newest"
            }
            resp = requests.get(BASE_URL, params=params)
            data = resp.json()

            results = data.get("response", {}).get("results", [])
            if not results:
                break

            for article in results:
                id = str(uuid.uuid4())
                fields = article.get("fields", {})
                thumbnail = fields.get("thumbnail","")
                headline = fields.get("headline", "")
                author = fields.get("byline", "")
                
                body = extract_plain_text(fields)
                row = [
                    id,
                    article.get("webTitle", ""),
                    headline,
                    article.get("webUrl", ""),
                    thumbnail,
                    article.get("sectionName", ""),
                    article.get("webPublicationDate", ""),
                    fields.get("trailText", ""),
                    body,
                    author
                ]
                writer.writerow(row)
                all_articles.append(row)

            print(f"Page {page} done, got {len(results)} articles.")
            sleep(1)  # polite delay

    print(f"Saved {len(all_articles)} articles to {output_file}")
    return all_articles

# %%
pages = 1
all_articles = crawl_guardian(pages)  # adjust number of pages
cols = ["id","title", "headline", "url", "thumbnail", "section","published_at","description","body", "author"]
all_articles = [dict(zip(cols, row)) for row in all_articles]

import pickle
with open(f"D:/DH/Senior/Paperboy/src/pickled_data/raw_crawl_{pages}.pkl", "wb") as f:
    pickle.dump(all_articles, f)  
print(f"Pickled {len(all_articles)} stories.")
# Out:
# Page 1 done, got 200 articles.
# Page 2 done, got 200 articles.
# Page 3 done, got 200 articles.
# Page 4 done, got 200 articles.
# Page 5 done, got 200 articles.
# %%
import sys, time, random
sys.path.append("D:/DH/Senior/Paperboy")  
from src.api.embedding.embedding import embed_bgem3

count = 0
failed = []

for i, doc in enumerate(all_articles):
    text = f"{doc['title']}\n\n{doc['description']}"
    if len(text) > 4000:
        text = text[:4000]

    while True:  # keep retrying until success
        try:
            embedded = embed_bgem3(text)
            data = embedded.get("data", None)

            if data:
                doc['embedding'] = data[0]  # add embedding
                print(f"✅ Embedded article {i+1}/{len(all_articles)}")
                break  # success, move on
            else:
                print(f"⚠️ Empty response for article {i}, retrying...")
            
        except Exception as e:
            print(f"❌ Error on article {i}: {e}. Retrying...")

        # exponential backoff with jitter
        sleep_time = min(60, 2 ** min(6, count)) + random.random()
        time.sleep(sleep_time)

    count += 1

print(f"\nFinished. Embedded {count} articles. Failed: {failed}")
# Out:
# ✅ Embedded article 1/1000
# ✅ Embedded article 2/1000
# ✅ Embedded article 3/1000
# ✅ Embedded article 4/1000
# ✅ Embedded article 5/1000
# ✅ Embedded article 6/1000
# ✅ Embedded article 7/1000
# ✅ Embedded article 8/1000
# ✅ Embedded article 9/1000
# ✅ Embedded article 10/1000
# ✅ Embedded article 11/1000
# ✅ Embedded article 12/1000
# ✅ Embedded article 13/1000
# ✅ Embedded article 14/1000
# ✅ Embedded article 15/1000
# ✅ Embedded article 16/1000
# ✅ Embedded article 17/1000
# ✅ Embedded article 18/1000
# ✅ Embedded article 19/1000
# ✅ Embedded article 20/1000
# ✅ Embedded article 21/1000
# ✅ Embedded article 22/1000
# ✅ Embedded article 23/1000
# ✅ Embedded article 24/1000
# ✅ Embedded article 25/1000
# ✅ Embedded article 26/1000
# ✅ Embedded article 27/1000
# ✅ Embedded article 28/1000
# ✅ Embedded article 29/1000
# ✅ Embedded article 30/1000
# ✅ Embedded article 31/1000
# ✅ Embedded article 32/1000
# ✅ Embedded article 33/1000
# ✅ Embedded article 34/1000
# ✅ Embedded article 35/1000
# ✅ Embedded article 36/1000
# ✅ Embedded article 37/1000
# ✅ Embedded article 38/1000
# ✅ Embedded article 39/1000
# ✅ Embedded article 40/1000
# ✅ Embedded article 41/1000
# ✅ Embedded article 42/1000
# ✅ Embedded article 43/1000
# ✅ Embedded article 44/1000
# ✅ Embedded article 45/1000
# ✅ Embedded article 46/1000
# ✅ Embedded article 47/1000
# ✅ Embedded article 48/1000
# ✅ Embedded article 49/1000
# ✅ Embedded article 50/1000
# ✅ Embedded article 51/1000
# ✅ Embedded article 52/1000
# ✅ Embedded article 53/1000
# ✅ Embedded article 54/1000
# ✅ Embedded article 55/1000
# ✅ Embedded article 56/1000
# ✅ Embedded article 57/1000
# ✅ Embedded article 58/1000
# ✅ Embedded article 59/1000
# ✅ Embedded article 60/1000
# ✅ Embedded article 61/1000
# ✅ Embedded article 62/1000
# ✅ Embedded article 63/1000
# ✅ Embedded article 64/1000
# ✅ Embedded article 65/1000
# ✅ Embedded article 66/1000
# ✅ Embedded article 67/1000
# ✅ Embedded article 68/1000
# ✅ Embedded article 69/1000
# ✅ Embedded article 546/1000
# ✅ Embedded article 547/1000
# ✅ Embedded article 548/1000
# ✅ Embedded article 549/1000
# ✅ Embedded article 550/1000
# ✅ Embedded article 551/1000
# ✅ Embedded article 552/1000
# ✅ Embedded article 553/1000
# ✅ Embedded article 554/1000
# ✅ Embedded article 555/1000
# ✅ Embedded article 556/1000
# ✅ Embedded article 557/1000
# ✅ Embedded article 558/1000
# ✅ Embedded article 559/1000
# ✅ Embedded article 560/1000
# ✅ Embedded article 561/1000
# ✅ Embedded article 562/1000
# ✅ Embedded article 563/1000
# ✅ Embedded article 564/1000
# ✅ Embedded article 565/1000
# ✅ Embedded article 566/1000
# ✅ Embedded article 567/1000
# ✅ Embedded article 568/1000
# ✅ Embedded article 569/1000
# ✅ Embedded article 570/1000
# ✅ Embedded article 571/1000
# ✅ Embedded article 572/1000
# ✅ Embedded article 573/1000
# ✅ Embedded article 574/1000
# ✅ Embedded article 575/1000
# ✅ Embedded article 576/1000
# ✅ Embedded article 577/1000
# ✅ Embedded article 578/1000
# ✅ Embedded article 579/1000
# ✅ Embedded article 580/1000
# ✅ Embedded article 581/1000
# ✅ Embedded article 582/1000
# ✅ Embedded article 583/1000
# ✅ Embedded article 584/1000
# ✅ Embedded article 585/1000
# ✅ Embedded article 586/1000
# ✅ Embedded article 587/1000
# ✅ Embedded article 588/1000
# ✅ Embedded article 589/1000
# ✅ Embedded article 590/1000
# ✅ Embedded article 591/1000
# ✅ Embedded article 592/1000
# ✅ Embedded article 593/1000
# ✅ Embedded article 594/1000
# ✅ Embedded article 595/1000
# ✅ Embedded article 596/1000
# ✅ Embedded article 597/1000
# ✅ Embedded article 598/1000
# ✅ Embedded article 599/1000
# ✅ Embedded article 600/1000
# ✅ Embedded article 601/1000
# ✅ Embedded article 602/1000
# ✅ Embedded article 603/1000
# ✅ Embedded article 604/1000
# ✅ Embedded article 605/1000
# ✅ Embedded article 606/1000
# ✅ Embedded article 607/1000
# ✅ Embedded article 608/1000
# ✅ Embedded article 609/1000
# ✅ Embedded article 610/1000
# ✅ Embedded article 611/1000
# ✅ Embedded article 612/1000
# ✅ Embedded article 613/1000
# ✅ Embedded article 614/1000
# ✅ Embedded article 615/1000
# ✅ Embedded article 616/1000
# ✅ Embedded article 617/1000
# ✅ Embedded article 618/1000
# ✅ Embedded article 619/1000
# ✅ Embedded article 620/1000
# ✅ Embedded article 621/1000
# ✅ Embedded article 622/1000
# ✅ Embedded article 623/1000
# ✅ Embedded article 624/1000
# ✅ Embedded article 625/1000
# ✅ Embedded article 626/1000
# ✅ Embedded article 627/1000
# ✅ Embedded article 628/1000
# ✅ Embedded article 629/1000
# ✅ Embedded article 630/1000
# ✅ Embedded article 631/1000
# ✅ Embedded article 632/1000
# ✅ Embedded article 633/1000
# ✅ Embedded article 634/1000
# ✅ Embedded article 635/1000
# ✅ Embedded article 636/1000
# ✅ Embedded article 637/1000
# ✅ Embedded article 638/1000
# ✅ Embedded article 639/1000
# ✅ Embedded article 640/1000
# ✅ Embedded article 641/1000
# ✅ Embedded article 642/1000
# ✅ Embedded article 643/1000
# ✅ Embedded article 644/1000
# ✅ Embedded article 645/1000
# ✅ Embedded article 646/1000
# ✅ Embedded article 647/1000
# ✅ Embedded article 648/1000
# ✅ Embedded article 649/1000
# ✅ Embedded article 650/1000
# ✅ Embedded article 651/1000
# ✅ Embedded article 652/1000
# ✅ Embedded article 653/1000
# ✅ Embedded article 654/1000
# ✅ Embedded article 655/1000
# ✅ Embedded article 656/1000
# ✅ Embedded article 657/1000
# ✅ Embedded article 658/1000
# ✅ Embedded article 659/1000
# ✅ Embedded article 660/1000
# ✅ Embedded article 661/1000
# ✅ Embedded article 662/1000
# ✅ Embedded article 663/1000
# ✅ Embedded article 664/1000
# ✅ Embedded article 665/1000
# ✅ Embedded article 666/1000
# ✅ Embedded article 667/1000
# ✅ Embedded article 668/1000
# ✅ Embedded article 669/1000
# ✅ Embedded article 670/1000
# ✅ Embedded article 671/1000
# ✅ Embedded article 672/1000
# ✅ Embedded article 673/1000
# ✅ Embedded article 674/1000
# ✅ Embedded article 675/1000
# ✅ Embedded article 676/1000
# ✅ Embedded article 677/1000
# ✅ Embedded article 678/1000
# ✅ Embedded article 679/1000
# ✅ Embedded article 680/1000
# ✅ Embedded article 681/1000
# ✅ Embedded article 682/1000
# ✅ Embedded article 683/1000
# ✅ Embedded article 684/1000
# ✅ Embedded article 685/1000
# ✅ Embedded article 686/1000
# ✅ Embedded article 687/1000
# ✅ Embedded article 688/1000
# ✅ Embedded article 689/1000
# ✅ Embedded article 690/1000
# ✅ Embedded article 691/1000
# ✅ Embedded article 692/1000
# ✅ Embedded article 693/1000
# ✅ Embedded article 694/1000
# ✅ Embedded article 695/1000
# ✅ Embedded article 696/1000
# ✅ Embedded article 697/1000
# ✅ Embedded article 698/1000
# ✅ Embedded article 699/1000
# ✅ Embedded article 700/1000
# ✅ Embedded article 701/1000
# ✅ Embedded article 702/1000
# ✅ Embedded article 703/1000
# ✅ Embedded article 704/1000
# ✅ Embedded article 705/1000
# ✅ Embedded article 706/1000
# ✅ Embedded article 707/1000
# ✅ Embedded article 708/1000
# ✅ Embedded article 709/1000
# ✅ Embedded article 710/1000
# ✅ Embedded article 711/1000
# ✅ Embedded article 712/1000
# ✅ Embedded article 713/1000
# ✅ Embedded article 714/1000
# ✅ Embedded article 715/1000
# ✅ Embedded article 716/1000
# ✅ Embedded article 717/1000
# ✅ Embedded article 718/1000
# ✅ Embedded article 719/1000
# ✅ Embedded article 720/1000
# ✅ Embedded article 721/1000
# ✅ Embedded article 722/1000
# ✅ Embedded article 723/1000
# ✅ Embedded article 724/1000
# ✅ Embedded article 725/1000
# ✅ Embedded article 726/1000
# ✅ Embedded article 727/1000
# ✅ Embedded article 728/1000
# ✅ Embedded article 729/1000
# ✅ Embedded article 730/1000
# ✅ Embedded article 731/1000
# ✅ Embedded article 732/1000
# ✅ Embedded article 733/1000
# ✅ Embedded article 734/1000
# ✅ Embedded article 735/1000
# ✅ Embedded article 736/1000
# ✅ Embedded article 737/1000
# ✅ Embedded article 738/1000
# ✅ Embedded article 739/1000
# ✅ Embedded article 740/1000
# ✅ Embedded article 741/1000
# ✅ Embedded article 742/1000
# ✅ Embedded article 743/1000
# ✅ Embedded article 744/1000
# ✅ Embedded article 745/1000
# ✅ Embedded article 746/1000
# ✅ Embedded article 747/1000
# ✅ Embedded article 748/1000
# ✅ Embedded article 749/1000
# ✅ Embedded article 750/1000
# ✅ Embedded article 751/1000
# ✅ Embedded article 752/1000
# ✅ Embedded article 753/1000
# ✅ Embedded article 754/1000
# ✅ Embedded article 755/1000
# ✅ Embedded article 756/1000
# ✅ Embedded article 757/1000
# ✅ Embedded article 758/1000
# ✅ Embedded article 759/1000
# ✅ Embedded article 760/1000
# ✅ Embedded article 761/1000
# ✅ Embedded article 762/1000
# ✅ Embedded article 763/1000
# ✅ Embedded article 764/1000
# ✅ Embedded article 765/1000
# ✅ Embedded article 766/1000
# ✅ Embedded article 767/1000
# ✅ Embedded article 768/1000
# ✅ Embedded article 769/1000
# ✅ Embedded article 770/1000
# ✅ Embedded article 771/1000
# ✅ Embedded article 772/1000
# ✅ Embedded article 773/1000
# ✅ Embedded article 774/1000
# ✅ Embedded article 775/1000
# ✅ Embedded article 776/1000
# ✅ Embedded article 777/1000
# ✅ Embedded article 778/1000
# ✅ Embedded article 779/1000
# ✅ Embedded article 780/1000
# ✅ Embedded article 781/1000
# ✅ Embedded article 782/1000
# ✅ Embedded article 783/1000
# ✅ Embedded article 784/1000
# ✅ Embedded article 785/1000
# ✅ Embedded article 786/1000
# ✅ Embedded article 787/1000
# ✅ Embedded article 788/1000
# ✅ Embedded article 789/1000
# ✅ Embedded article 790/1000
# ✅ Embedded article 791/1000
# ✅ Embedded article 792/1000
# ✅ Embedded article 793/1000
# ✅ Embedded article 794/1000
# ✅ Embedded article 795/1000
# ✅ Embedded article 796/1000
# ✅ Embedded article 797/1000
# ✅ Embedded article 798/1000
# ✅ Embedded article 799/1000
# ✅ Embedded article 800/1000
# ✅ Embedded article 801/1000
# ✅ Embedded article 802/1000
# ✅ Embedded article 803/1000
# ✅ Embedded article 804/1000
# ✅ Embedded article 805/1000
# ✅ Embedded article 806/1000
# ✅ Embedded article 807/1000
# ✅ Embedded article 808/1000
# ✅ Embedded article 809/1000
# ✅ Embedded article 810/1000
# ✅ Embedded article 811/1000
# ✅ Embedded article 812/1000
# ✅ Embedded article 813/1000
# ✅ Embedded article 814/1000
# ✅ Embedded article 815/1000
# ✅ Embedded article 816/1000
# ✅ Embedded article 817/1000
# ✅ Embedded article 818/1000
# ✅ Embedded article 819/1000
# ✅ Embedded article 820/1000
# ✅ Embedded article 821/1000
# ✅ Embedded article 822/1000
# ✅ Embedded article 823/1000
# ✅ Embedded article 824/1000
# ✅ Embedded article 825/1000
# ✅ Embedded article 826/1000
# ✅ Embedded article 827/1000
# ✅ Embedded article 828/1000
# ✅ Embedded article 829/1000
# ✅ Embedded article 830/1000
# ✅ Embedded article 831/1000
# ✅ Embedded article 832/1000
# ✅ Embedded article 833/1000
# ✅ Embedded article 834/1000
# ✅ Embedded article 835/1000
# ✅ Embedded article 836/1000
# ✅ Embedded article 837/1000
# ✅ Embedded article 838/1000
# ✅ Embedded article 839/1000
# ✅ Embedded article 840/1000
# ✅ Embedded article 841/1000
# ✅ Embedded article 842/1000
# ✅ Embedded article 843/1000
# ✅ Embedded article 844/1000
# ✅ Embedded article 845/1000
# ✅ Embedded article 846/1000
# ✅ Embedded article 847/1000
# ✅ Embedded article 848/1000
# ✅ Embedded article 849/1000
# ✅ Embedded article 850/1000
# ✅ Embedded article 851/1000
# ✅ Embedded article 852/1000
# ✅ Embedded article 853/1000
# ✅ Embedded article 854/1000
# ✅ Embedded article 855/1000
# ✅ Embedded article 856/1000
# ✅ Embedded article 857/1000
# ✅ Embedded article 858/1000
# ✅ Embedded article 859/1000
# ✅ Embedded article 860/1000
# ✅ Embedded article 861/1000
# ✅ Embedded article 862/1000
# ✅ Embedded article 863/1000
# ✅ Embedded article 864/1000
# ✅ Embedded article 865/1000
# ✅ Embedded article 866/1000
# ✅ Embedded article 867/1000
# ✅ Embedded article 868/1000
# ✅ Embedded article 869/1000
# ✅ Embedded article 870/1000
# ✅ Embedded article 871/1000
# ✅ Embedded article 872/1000
# ✅ Embedded article 873/1000
# ✅ Embedded article 874/1000
# ✅ Embedded article 875/1000
# ✅ Embedded article 876/1000
# ✅ Embedded article 877/1000
# ✅ Embedded article 878/1000
# ✅ Embedded article 879/1000
# ✅ Embedded article 880/1000
# ✅ Embedded article 881/1000
# ✅ Embedded article 882/1000
# ✅ Embedded article 883/1000
# ✅ Embedded article 884/1000
# ✅ Embedded article 885/1000
# ✅ Embedded article 886/1000
# ✅ Embedded article 887/1000
# ✅ Embedded article 888/1000
# ✅ Embedded article 889/1000
# ✅ Embedded article 890/1000
# ✅ Embedded article 891/1000
# ✅ Embedded article 892/1000
# ✅ Embedded article 893/1000
# ✅ Embedded article 894/1000
# ✅ Embedded article 895/1000
# ✅ Embedded article 896/1000
# ✅ Embedded article 897/1000
# ✅ Embedded article 898/1000
# ✅ Embedded article 899/1000
# ✅ Embedded article 900/1000
# ✅ Embedded article 901/1000
# ✅ Embedded article 902/1000
# ✅ Embedded article 903/1000
# ✅ Embedded article 904/1000
# ✅ Embedded article 905/1000
# ✅ Embedded article 906/1000
# ✅ Embedded article 907/1000
# ✅ Embedded article 908/1000
# ✅ Embedded article 909/1000
# ✅ Embedded article 910/1000
# ✅ Embedded article 911/1000
# ✅ Embedded article 912/1000
# ✅ Embedded article 913/1000
# ✅ Embedded article 914/1000
# ✅ Embedded article 915/1000
# ✅ Embedded article 916/1000
# ✅ Embedded article 917/1000
# ✅ Embedded article 918/1000
# ✅ Embedded article 919/1000
# ✅ Embedded article 920/1000
# ✅ Embedded article 921/1000
# ✅ Embedded article 922/1000
# ✅ Embedded article 923/1000
# ✅ Embedded article 924/1000
# ✅ Embedded article 925/1000
# ✅ Embedded article 926/1000
# ✅ Embedded article 927/1000
# ✅ Embedded article 928/1000
# ✅ Embedded article 929/1000
# ✅ Embedded article 930/1000
# ✅ Embedded article 931/1000
# ✅ Embedded article 932/1000
# ✅ Embedded article 933/1000
# ✅ Embedded article 934/1000
# ✅ Embedded article 935/1000
# ✅ Embedded article 936/1000
# ✅ Embedded article 937/1000
# ✅ Embedded article 938/1000
# ✅ Embedded article 939/1000
# ✅ Embedded article 940/1000
# ✅ Embedded article 941/1000
# ✅ Embedded article 942/1000
# ✅ Embedded article 943/1000
# ✅ Embedded article 944/1000
# ✅ Embedded article 945/1000
# ✅ Embedded article 946/1000
# ✅ Embedded article 947/1000
# ✅ Embedded article 948/1000
# ✅ Embedded article 949/1000
# ✅ Embedded article 950/1000
# ✅ Embedded article 951/1000
# ✅ Embedded article 952/1000
# ✅ Embedded article 953/1000
# ✅ Embedded article 954/1000
# ✅ Embedded article 955/1000
# ✅ Embedded article 956/1000
# ✅ Embedded article 957/1000
# ✅ Embedded article 958/1000
# ✅ Embedded article 959/1000
# ✅ Embedded article 960/1000
# ✅ Embedded article 961/1000
# ✅ Embedded article 962/1000
# ✅ Embedded article 963/1000
# ✅ Embedded article 964/1000
# ✅ Embedded article 965/1000
# ✅ Embedded article 966/1000
# ✅ Embedded article 967/1000
# ✅ Embedded article 968/1000
# ✅ Embedded article 969/1000
# ✅ Embedded article 970/1000
# ✅ Embedded article 971/1000
# ✅ Embedded article 972/1000
# ✅ Embedded article 973/1000
# ✅ Embedded article 974/1000
# ✅ Embedded article 975/1000
# ✅ Embedded article 976/1000
# ✅ Embedded article 977/1000
# ✅ Embedded article 978/1000
# ✅ Embedded article 979/1000
# ✅ Embedded article 980/1000
# ✅ Embedded article 981/1000
# ✅ Embedded article 982/1000
# ✅ Embedded article 983/1000
# ✅ Embedded article 984/1000
# ✅ Embedded article 985/1000
# ✅ Embedded article 986/1000
# ✅ Embedded article 987/1000
# ✅ Embedded article 988/1000
# ✅ Embedded article 989/1000
# ✅ Embedded article 990/1000
# ✅ Embedded article 991/1000
# ✅ Embedded article 992/1000
# ✅ Embedded article 993/1000
# ✅ Embedded article 994/1000
# ✅ Embedded article 995/1000
# ✅ Embedded article 996/1000
# ✅ Embedded article 997/1000
# ✅ Embedded article 998/1000
# ✅ Embedded article 999/1000
# ✅ Embedded article 1000/1000
#
# Finished. Embedded 1000 articles. Failed: []

# %%
from pathlib import Path
import pickle

ROOT = Path("d:/DH/Senior/Paperboy/src")  # your project root
file_path = ROOT / "pickled_data" / f"articles_{pages}.pkl"

with open(file_path, "wb") as f:
    pickle.dump(all_articles, f)

print("Loaded:", len(all_articles))
# Out:
# Loaded: 1000

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\dh\senior\paperboy\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.23.2 in d:\dh\senior\paperboy\.venv\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\dh\senior\paperboy\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\dh\senior\paperboy\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\dh\senior\paperboy\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\dh\senior\paperboy\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

#
.058013916015625, -0.0007719993591308594, -0.03411865234375, -0.040191650390625, 0.0053863525390625, -0.0005040168762207031, -0.034942626953125, -0.01446533203125, 0.002079010009765625, -0.067138671875, 0.004573822021484375, 0.034820556640625, 0.00498199462890625, -0.0056610107421875, 0.041900634765625, -0.0816650390625, 0.0266571044921875, -0.0517578125, -0.05108642578125, 0.04168701171875, -0.032135009765625, 0.040496826171875, 0.0057220458984375, 0.052703857421875, 0.0297698974609375, 0.001041412353515625, -0.055694580078125, -0.047027587890625, -0.00290679931640625, 0.02740478515625, 0.027008056640625, -0.0034618377685546875, 0.023284912109375, 0.04351806640625, 0.0107574462890625, 0.0281829833984375, 0.00603485107421875, -0.0207366943359375, 0.00897216796875, 0.044158935546875, -0.0133209228515625, 0.0017557144165039062, -0.01495361328125, -0.0147857666015625, 0.00861358642578125, 0.013397216796875, -0.001953125, -0.022308349609375, -0.03350830078125, 0.0439453125, -0.01464080810546875, 0.040802001953125, 0.0096588134765625, -0.05126953125, -0.0301055908203125, -0.0031299591064453125, -0.05291748046875, ...

# %%
import psycopg2

def get_connection():
    return psycopg2.connect(
        host="localhost",
        port=5436,
        dbname="paperboy",
        user="minhhieu",
        password="minhhieu888"
    )

# UPSERT function
def upsert_articles(all_articles):
    sql = """
    INSERT INTO articles (id, title, headline, url, thumbnail, section, published_at, description, body, author, embedding)
    VALUES (%(id)s, %(title)s, %(headline)s, %(url)s, %(thumbnail)s, %(section)s, %(published_at)s, %(description)s, %(body)s, %(author)s, %(embedding)s)
    ON CONFLICT (id) DO NOTHING;
    """


    with get_connection() as conn:
        with conn.cursor() as cur:
            cur.executemany(sql, all_articles)  # batch insert
        conn.commit()
    print(f"Upserted {len(all_articles)} articles.")

# %%
empty_count = sum(1 for a in all_articles if not a.get("author"))
print(empty_count)
# Out:
# 31

# %%
# for i, article in enumerate(all_articles):
#     try:
#         if article['embedding'] == None:
#             text = f"{article['title']}\n\n{article['description']}"
#             if len(text) > 4000:
#                 text = text[:4000]
#             embedded = embed_bgem3(text)
#             data = embedded.get("data", None)
#             if data:
#                 article['embedding'] = data[0]  # add embedding
#             print(f"Embedded article {article['title']}")
#         else:
#             continue
#     except:
#         text = f"{article['title']}\n\n{article['description']}"
#         if len(text) > 4000:
#             text = text[:4000]
#         embedded = embed_bgem3(text)
#         data = embedded.get("data", None)
#         if data:
#             article['embedding'] = data[0]  # add embedding
#             print(f"Embedded article {article['title']}")

# %%
upsert_articles(all_articles)
# Out:
# Upserted 1000 articles.

# %%
empty_text_count = 0
empty_full_text_count = 0

for article in all_articles:
    if article['embedding'] == None:
        empty_text_count += 1
    if article['title'] == "":
        empty_full_text_count += 1

total = len(all_articles)
print(f"Total articles: {total}")
print(f"Articles with empty 'text': {empty_text_count} ({empty_text_count/total*100:.2f}%)")
print(f"Articles with empty 'full_text': {empty_full_text_count} ({empty_full_text_count/total*100:.2f}%)")
# Out:
# Total articles: 1000
# Articles with empty 'text': 0 (0.00%)
# Articles with empty 'full_text': 0 (0.00%)
